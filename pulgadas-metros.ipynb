# %%
#Importar librerias
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
#Declaramos los eventos pasados
entrada=np.array([1,6,30,7,70,43,503,201,1005,99],dtype=float)

resultados=np.array([0.0254, 0.1524, 0.762, 0.1778, 1.778, 1.0922, 12.776, 5.1054, 25.527, 2.514], dtype=float)

# %%
#Topografía de la red
capa1 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
#Creamos el tpo de red
modelo = tf.keras.Sequential([capa1])

# %%
# Asigna el optimizador y la métrica de pérdida
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_squared_error'
)

print("Entrenando la red")
# Out:
# Entrenando la red

# %%
#Entrenamiento del modelo
entrenamiento=modelo.fit(entrada, resultados, epochs=500, verbose=True)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 1s/step - loss: 92535.0312
# Epoch 2/500
# 1/1 [==============================] - 0s 18ms/step - loss: 71715.1016
# Epoch 3/500
# 1/1 [==============================] - 0s 10ms/step - loss: 53634.8203
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 38319.7500
# Epoch 5/500
# 1/1 [==============================] - 0s 15ms/step - loss: 25759.9824
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 15898.4482
# Epoch 7/500
# 1/1 [==============================] - 0s 18ms/step - loss: 8619.1201
# Epoch 8/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3735.4507
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 982.2977
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 15.9870
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 426.4967
# Epoch 12/500
# ...

# %%
# Cargar el modelo previamente entrenado
modelo = tf.keras.models.load_model('RedNeuronal.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\CARLOS\RN_ARTIFICIAL\PulgadasMetros.ipynb Celda 7 line 2
#       <a href='vscode-notebook-cell:/c%3A/CARLOS/RN_ARTIFICIAL/PulgadasMetros.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> # Cargar el modelo previamente entrenado
# ----> <a href='vscode-notebook-cell:/c%3A/CARLOS/RN_ARTIFICIAL/PulgadasMetros.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> modelo = tf.keras.models.load_model('RedNeuronal.h5')
#
# NameError: name 'tf' is not defined

# %%
#Guardar la red
modelo.save('RedNeuronal.h5')
modelo.save_weights('peso.h5')
# Out:
# c:\Users\EDR\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#Observar el comportamiento de nuetra red
plt.xlabel('Ciclos de entrenamiento')
plt.ylabel('Errores')
plt.plot(entrenamiento.history["loss"])
plt.show()

# %%
#Prediccion
i=input("Ingresar el valor en pulgadas:")
i=float(i)

prediccion=modelo.predict([i])

print("El valor en pulgadas: ", i)
print("El valor en metros: ", str(prediccion))
# Out:
# 1/1 [==============================] - 0s 63ms/step
# El valor en pulgadas:  720.0
# El valor en metros:  [[18.276583]]
